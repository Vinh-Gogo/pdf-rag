# %%
# !pip install marker-pdf

# %%
# !marker src\data\pdfs\in --output_format markdown --output_dir src\data\pdfs\out
# Out:
# 2025-11-22 04:10:31.105448: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763784631.130879    1611 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763784631.137731    1611 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763784631.155147    1611 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from marker.converters.pdf import PdfConverter
from marker.models import create_model_dict
from marker.output import text_from_rendered

converter = PdfConverter(
    artifact_dict=create_model_dict(),
)
rendered = converter("src/data/pdfs/in/file_2.pdf")
text, _, images = text_from_rendered(rendered)
# Out:
# ...
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
# ...
#
#
# ...
#
#
#
#
#
# ...
#
# ...
#
# ...
#
# ...
#
#
# ...
#
#
#
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
#
#
#
# ...
#
#
#
#
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2423800766.py in <cell line: 0>()
#       6     artifact_dict=create_model_dict(),
#       7 )
# ----> 8 rendered = converter("src/data/pdfs/in/file_2.pdf")
#       9 text, _, images = text_from_rendered(rendered)
#
# /usr/local/lib/python3.12/dist-packages/marker/converters/pdf.py in __call__(self, filepath)
#     193     def __call__(self, filepath: str | io.BytesIO):
#     194         with self.filepath_to_str(filepath) as temp_path:
# --> 195             document = self.build_document(temp_path)
#     196             self.page_count = len(document.pages)
#     197             renderer = self.resolve_dependencies(self.renderer)
#
# ...

# %%
from marker.converters.pdf import PdfConverter
from marker.models import create_model_dict
from marker.config.parser import ConfigParser

config = {
    "output_format": "markdown",
    "ADDITIONAL_KEY": "VALUE"
}
config_parser = ConfigParser(config)

converter = PdfConverter(
    config=config_parser.generate_config_dict(),
    artifact_dict=create_model_dict(),
    processor_list=config_parser.get_processors(),
    renderer=config_parser.get_renderer(),
    llm_service=config_parser.get_llm_service()
)
rendered = converter("../data/pdfs/in/file_2.pdf")
text, _, images = text_from_rendered(rendered)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from marker.converters.pdf import PdfConverter
from marker.models import create_model_dict
from marker.config.parser import ConfigParser
from marker.output import text_from_rendered   # <-- Quan trọng!

config = {
    "output_format": "markdown"
}

config_parser = ConfigParser(config)

converter = PdfConverter(
    config=config_parser.generate_config_dict(),
    artifact_dict=create_model_dict(),
    processor_list=config_parser.get_processors(),
    renderer=config_parser.get_renderer(),
    llm_service=config_parser.get_llm_service()
)

# PdfConverter là callable
rendered = converter("../data/pdfs/in/file_2.pdf")

# Trích xuất text, meta, ảnh
text, meta, images = text_from_rendered(rendered)

print(text)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# -------------  cell start  -------------
from pathlib import Path
from marker.converters.pdf import PdfConverter
from marker.models import create_model_dict
from marker.config.parser import ConfigParser
from marker.output import text_from_rendered   #  <-- 1. missing import

config = {
    "output_format": "markdown",
    "ADDITIONAL_KEY": "VALUE"
}
config_parser = ConfigParser(config)

converter = PdfConverter(
    config=config_parser.generate_config_dict(),
    artifact_dict=create_model_dict(),
    processor_list=config_parser.get_processors(),
    renderer=config_parser.get_renderer(),
    llm_service=config_parser.get_llm_service()
)

pdf_path = Path(r"../data/pdfs/in/file_2.pdf")  #  <-- 2. wrap in Path
rendered = converter(pdf_path)
text, _, images = text_from_rendered(rendered)
print(text[:500])          # quick sanity check
# -------------  cell end  ---------------
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3060537327.py in <cell line: 0>()
#      21
#      22 pdf_path = Path(r"../data/pdfs/in/file_2.pdf")  #  <-- 2. wrap in Path
# ---> 23 rendered = converter(pdf_path)
#      24 text, _, images = text_from_rendered(rendered)
#      25 print(text[:500])          # quick sanity check
#
# /usr/local/lib/python3.12/dist-packages/marker/converters/pdf.py in __call__(self, filepath)
#     192
#     193     def __call__(self, filepath: str | io.BytesIO):
# --> 194         with self.filepath_to_str(filepath) as temp_path:
#     195             document = self.build_document(temp_path)
#     196             self.page_count = len(document.pages)
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
# ...

# %%
from marker.converters.pdf import PdfConverter
from marker.models import create_model_dict
from marker.config.parser import ConfigParser
from marker.output import text_from_rendered   #  <-- still needed

config = {"output_format": "markdown", "ADDITIONAL_KEY": "VALUE"}
config_parser = ConfigParser(config)

converter = PdfConverter(
    config=config_parser.generate_config_dict(),
    artifact_dict=create_model_dict(),
    processor_list=config_parser.get_processors(),
    renderer=config_parser.get_renderer(),
    llm_service=config_parser.get_llm_service()
)

pdf_file = "../data/pdfs/in/file_2.pdf"   #  <-- plain string
rendered = converter(pdf_file)
text, _, images = text_from_rendered(rendered)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
