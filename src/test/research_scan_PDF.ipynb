# %%
# %pip install pytesseract
# %pip install ocrmypdf
# Out:
# Requirement already satisfied: pytesseract in d:\wetec\rag\.venv\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in d:\wetec\rag\.venv\lib\site-packages (from pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in d:\wetec\rag\.venv\lib\site-packages (from pytesseract) (12.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting ocrmypdf
#   Downloading ocrmypdf-16.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting deprecation>=2.1.0 (from ocrmypdf)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting img2pdf>=0.5 (from ocrmypdf)
#   Downloading img2pdf-0.6.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=20 in d:\wetec\rag\.venv\lib\site-packages (from ocrmypdf) (25.0)
# Requirement already satisfied: pdfminer-six>=20220319 in d:\wetec\rag\.venv\lib\site-packages (from ocrmypdf) (20251107)
# Collecting pi-heif (from ocrmypdf)
#   Downloading pi_heif-1.1.1-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Collecting pikepdf>=10 (from ocrmypdf)
#   Downloading pikepdf-10.0.2-cp312-cp312-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: pillow>=10.0.1 in d:\wetec\rag\.venv\lib\site-packages (from ocrmypdf) (12.0.0)
# Collecting pluggy>=1 (from ocrmypdf)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting rich>=13 (from ocrmypdf)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in d:\wetec\rag\.venv\lib\site-packages (from pdfminer-six>=20220319->ocrmypdf) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in d:\wetec\rag\.venv\lib\site-packages (from pdfminer-six>=20220319->ocrmypdf) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in d:\wetec\rag\.venv\lib\site-packages (from cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (2.0.0)
# Requirement already satisfied: pycparser in d:\wetec\rag\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (2.23)
# Collecting Deprecated (from pikepdf>=10->ocrmypdf)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: lxml>=4.8 in d:\wetec\rag\.venv\lib\site-packages (from pikepdf>=10->ocrmypdf) (6.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich>=13->ocrmypdf)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\wetec\rag\.venv\lib\site-packages (from rich>=13->ocrmypdf) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13->ocrmypdf)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting wrapt<3,>=1.10 (from Deprecated->pikepdf>=10->ocrmypdf)
#   Downloading wrapt-2.0.1-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Downloading ocrmypdf-16.12.0-py3-none-any.whl (163 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading img2pdf-0.6.3-py3-none-any.whl (49 kB)
# Downloading pikepdf-10.0.2-cp312-cp312-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.7 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.7 MB 1.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.0/3.7 MB 2.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.1/3.7 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 4.3 MB/s  0:00:01
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading wrapt-2.0.1-cp312-cp312-win_amd64.whl (60 kB)
# Downloading pi_heif-1.1.1-cp312-cp312-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 11.6 MB/s  0:00:00
# Installing collected packages: wrapt, pluggy, pi-heif, mdurl, deprecation, markdown-it-py, Deprecated, rich, pikepdf, img2pdf, ocrmypdf
#
#    ----------------------------------------  0/11 [wrapt]
#    --- ------------------------------------  1/11 [pluggy]
#    --- ------------------------------------  1/11 [pluggy]
#    ------- --------------------------------  2/11 [pi-heif]
#    ---------- -----------------------------  3/11 [mdurl]
#    -------------- -------------------------  4/11 [deprecation]
#    ------------------ ---------------------  5/11 [markdown-it-py]
#    ------------------ ---------------------  5/11 [markdown-it-py]
#    ------------------ ---------------------  5/11 [markdown-it-py]
#    ------------------ ---------------------  5/11 [markdown-it-py]
#    ------------------ ---------------------  5/11 [markdown-it-py]
#    ------------------ ---------------------  5/11 [markdown-it-py]
#    ------------------ ---------------------  5/11 [markdown-it-py]
#    ------------------ ---------------------  5/11 [markdown-it-py]
#    ------------------ ---------------------  5/11 [markdown-it-py]
#    ------------------ ---------------------  5/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [Deprecated]
#    ------------------------- --------------  7/11 [rich]
#    ------------------------- --------------  7/11 [rich]
#    ------------------------- --------------  7/11 [rich]
#    ------------------------- --------------  7/11 [rich]
#    ------------------------- --------------  7/11 [rich]
#    ------------------------- --------------  7/11 [rich]
#    ------------------------- --------------  7/11 [rich]
#    ------------------------- --------------  7/11 [rich]
#    ------------------------- --------------  7/11 [rich]
#    ------------------------- --------------  7/11 [rich]
#    ----------------------------- ----------  8/11 [pikepdf]
#    ----------------------------- ----------  8/11 [pikepdf]
#    ----------------------------- ----------  8/11 [pikepdf]
#    ----------------------------- ----------  8/11 [pikepdf]
#    ----------------------------- ----------  8/11 [pikepdf]
#    -------------------------------- -------  9/11 [img2pdf]
#    -------------------------------- -------  9/11 [img2pdf]
#    -------------------------------- -------  9/11 [img2pdf]
#    ------------------------------------ --- 10/11 [ocrmypdf]
#    ------------------------------------ --- 10/11 [ocrmypdf]
#    ------------------------------------ --- 10/11 [ocrmypdf]
#    ------------------------------------ --- 10/11 [ocrmypdf]
#    ------------------------------------ --- 10/11 [ocrmypdf]
#    ------------------------------------ --- 10/11 [ocrmypdf]
#    ------------------------------------ --- 10/11 [ocrmypdf]
#    ------------------------------------ --- 10/11 [ocrmypdf]
#    ---------------------------------------- 11/11 [ocrmypdf]
#
# Successfully installed Deprecated-1.3.1 deprecation-2.1.0 img2pdf-0.6.3 markdown-it-py-4.0.0 mdurl-0.1.2 ocrmypdf-16.12.0 pi-heif-1.1.1 pikepdf-10.0.2 pluggy-1.6.0 rich-14.2.0 wrapt-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
print(pytesseract.get_tesseract_version())
# Out:
# 5.5.0.20241111

# %%
import pytesseract
from PIL import Image

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

text = pytesseract.image_to_string(Image.open(r"../data/images/page_5.png"), lang="vie")
print(text)
# Out:
# (5 ! Bóo cóo phót triển bền vững
#
# BIWASE NĂM 2024 - ĐỒNG HÀNH CÙNG 17 MỤC TIÊU
# PHÁT TRIỀN BỀN VỮNG CỦA LIÊN HỢP QUỐC (SDGs)
#
# Trong bối cảnh toàn cầu đang hướng đến một nền kinh tế xanh và phót triển bền vững, BIWASE
# không chỉ coi đây là một xu hướng mù còn là một cam kết mạnh mẽ, gắn liền với chiến lược
# phát triển dài hạn của doanh nghiệp. Với tróch nhiệm của một đơn vị tiên phong trong lĩnh vực
# môi trường và tời nguyên nước, BIWASE đã chủ động triển khơi nhiều giỏi pháp đồng bộ, áp
# dụng công nghệ tiên tiến và thúc đẩy mô hình kinh tế tuần hoàn nhằm tạo ra giá trị bền vững
# cho cỏ doanh nghiệp và cộng đồng.
#
# Không chỉ tập trung vào hiệu quỏ kinh dognh, BIWASE còn đặt trọng tôm vào việc bỏo vệ tòi
# nguyên, giảm thiểu tóc động tiêu cực đến môi trường và nâng cao chất Lượng cuộc sống. Những
# nỗ lực này không chỉ giúp công ty phát triển một cách vững chắc mà còn góp phần hiện thực
# hóa 17 Mục tiêu Phát triển Bền vững (SDGs) của Liên Hợp Quốc - kim chỉ nam cho sự phát triển
# hòi hòa giữa con người, hành tỉnh và thịnh vượng.
#
# Dưới đây Là những mục tiêu mò BIWASE đỡ và đang hướng đến trong hành trình xây dựng một
# tương Lại xanh, bền vững và thịnh vượng:
#
# 1. Tẳuĩuí J 2 ÍuỄ'ìạ Móa đi, N sức khủe & ffllộủ
# U L xóa nghềo Jv\f' sũng tốt
#
# s Toàn hệ thống BIWASE tợo việc làm ổn Bằng việc chú trọng cung cấp nước sạch đảm bảo
#
# định cho 2.416 người ơn toàn, BIWASE đõ góp phần giảm nguy cơ bệnh
# : tột liên quan đến nước bẩn gây ra, bỏo vệ sức khỏe
# cộng đồng cũng như giảm thiểu rủi ro về ô nhiễm
# môi trường. Hàng năm vào ngày Hội Hiến móu tình
# nguyện, lãnh đạo cùng đoàn viên thanh niên và
#
# * Quỹ bỏo vệ, chăm Lo đoàn viên và người
# Lao động: 4,29 tỷ đồng
# * 3,5 tỷ đồng bảo vệ, chăm Lo đoàn viên
#
# và người Lao động i người Iao động BIWASE đóng góp hơn 200 đơn vị
# * 16 tỷ đồng thăm hỏi, trợ cốp khó khăn . máu. BIWASE Luôn đảm bỏo tất cả CBNV đều được
# cho đồng bào gặp thiên tơi ở miền Bắc. tổ chức khám tổng quót định kỳ hàng năm.
#
# (UAIIY
#
# I ữlá0 dục HY — -.
# t Bình đáng giữ
# LÝ ]Ñ chấttượng ở khuu
#
# Công tác đào tạo, nâng cơo chất lượng . BIWASE khuyến khích bình đồng giới trong lực
#
# nguồn nhôn lực luôn được Ban lãnh đạo . lượng lạo động và tạo điều kiện phát triển nghề
# BIWASE chú trọng, bởi nhân sự giỏi là chìa nghiệp bình đẳng cho cỏ nam và nữ. Công ty luôn
# khóg thònh công của doanh nghiệp. khuyến khích sự tham gia của phụ nữ trong các
# Tính đến năm 2024, BIWASE đã tổ chức 34 hoạt động Công ty, đặc biệt là trong các vị trí quản
# khóa đùo tạo - 744 giờ đào tạo cho CBNV. lý, thúc đẩy bình đẳng giới trong môi trường Làm
#
# việc.

# %%
# !naps2.console --ocr lang=eng --output out.pdf --profile "MyScanner"
# Out:
# 'naps2.console' is not recognized as an internal or external command,
# operable program or batch file.
